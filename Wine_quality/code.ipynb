# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectFromModel

# %%
df1 = pd.read_csv('D:/BITS Work/Semester 2/Innovation/Projects/ml_projects/Wine_quality/winequality-red.csv', sep=';')
df2 = pd.read_csv('D:/BITS Work/Semester 2/Innovation/Projects/ml_projects/Wine_quality/winequality-white.csv', sep=';')

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#Currently we will work with only df2 and not merge it with df1
# for i in df2.columns:
#     plt.figure(figsize=(10,5))
#     sns.kdeplot(df2[i],df2["quality"])

# %%
# for i in df2.columns:
#     plt.figure(figsize=(10,5))
#     plt.scatter(df2[i],df2["quality"])

# %%
X_train = df2.iloc[:,:-1]
Y_train = df2.iloc[:,-1]
X_train, X_test, Y_train, Y_test = train_test_split(X_train,Y_train, random_state=0)
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1819            6.8              0.33         0.28             1.2      0.032
# 1021            8.6              0.20         0.42             1.5      0.041
# 4681            5.6              0.27         0.37             0.9      0.025
# 4018            6.4              0.18         0.48            18.0      0.054
# 1852            6.4              0.18         0.31             1.6      0.049
# ...             ...               ...          ...             ...        ...
# 4859            6.0              0.43         0.34             7.6      0.045
# 3264            5.9              0.24         0.12             1.4      0.035
# 1653            7.9              0.33         0.28            31.6      0.053
# 2607            8.9              0.26         0.33             8.1      0.024
# 2732            7.9              0.51         0.34             2.6      0.049
#
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
# rf = RandomForestClassifier()
# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# # Fit the random search model
# rf_random.fit(X_train, Y_train)

# %%
# rf_random.best_params_

# %%
model = RandomForestClassifier(n_estimators=800,min_samples_split=2,min_samples_leaf=1,
                               max_features='auto',max_depth=100,bootstrap=True).fit(X_train, Y_train)
print(model.score(X_train, Y_train), model.score(X_test,Y_test))
# Out:
# 1.0 0.6644897959183673

# %%
linreg = LogisticRegression().fit(X_train, Y_train)
print(linreg.score(X_train, Y_train), linreg.score(X_test,Y_test))
# Out:
# 0.5393411380343044 0.5044897959183674
# C:\Users\Rishabh Garg\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Rishabh Garg\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
knn = KNeighborsClassifier().fit(X_train, Y_train)
print(knn.score(X_train,Y_train),knn.score(X_test,Y_test))
# Out:
# 0.65151102640893 0.4595918367346939

# %%
dcf = DummyClassifier(strategy='most_frequent').fit(X_train,Y_train)
dcf.score(X_test,Y_test)
# Out:
# 0.42612244897959184

# %% [markdown]
# # Improving Random Forest Classifier:

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = RandomForestClassifier().fit(X_train,Y_train)
print(model.score(X_test,Y_test))
# Out:
# C:\Users\Rishabh Garg\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.636734693877551

# %%
X_train_scaled = scaler.fit_transform(X_train, Y_train)
X_test_scaled = scaler.transform(X_test)
model = RandomForestClassifier(n_estimators= 1800,
 min_samples_split= 2,
 min_samples_leaf= 1,
 max_features= 'sqrt',
 max_depth= None,
 bootstrap= True).fit(X_train_scaled,Y_train)
print(model.score(X_test_scaled,Y_test))
# Out:
# 0.6693877551020408

# %%
# rf = RandomForestClassifier()
# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=0, n_jobs = -1)
# # Fit the random search model
# rf_random.fit(X_train_scaled, Y_train)

# %%
# rf_random.best_params_

# %%
sfm = SelectFromModel(estimator = model)
sfm.fit(X_train,Y_train)
feature_names = sfm.get_support()
feature_names = X_train.columns[feature_names]

# %%
feature_names
# Out:
# Index(['volatile acidity', 'free sulfur dioxide', 'total sulfur dioxide',
#        'density', 'alcohol'],
#       dtype='object')

# %%
#Create a heatmap to understand correlations
corr = df1.corr()
piv = pd.pivot_table(corr, columns=df1.columns)
plt.figure(figsize=(10,10))
sns.heatmap(piv, annot=True)

# %%
corr = X_train.corr()
piv = pd.pivot_table(corr, columns=X_train.columns)
plt.figure(figsize=(10,10))
sns.heatmap(piv, annot=True)

# %%
X_train_temp = X_train[["volatile acidity","density","chlorides","alcohol","citric acid","sulphates"]]
X_test_temp = X_test[["volatile acidity","density","chlorides","alcohol","citric acid","sulphates"]]

# %%
model = RandomForestClassifier(n_estimators=800,min_samples_split=2,min_samples_leaf=1,
                               max_features='auto',max_depth=100,bootstrap=True).fit(X_train_temp, Y_train)
print(model.score(X_train_temp, Y_train), model.score(X_test_temp,Y_test))
# Out:
# 1.0 0.6310204081632653
